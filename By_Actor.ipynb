# %%
import pandas as pd

actor_blockchain = pd.read_csv('timeseries/blockchain_by_actor.csv', index_col=0)


# Remove lines where year = 0
actor_blockchain = actor_blockchain[actor_blockchain['year'] != 0]


# combine "year", "month", and "day" columns into a single datetime column
actor_blockchain['date'] = pd.to_datetime(actor_blockchain[['year', 'month', 'day']])

# drop the original "year", "month", and "day" columns
actor_blockchain.drop(columns=['year', 'month', 'day'], inplace=True)

actor_blockchain
# Out:
#                identity      received  nb_received       date     sum_fee  \
# 0        HappyCoins.com  1.377590e+09          4.0 2015-01-01     49596.0
# 1                   821  2.476057e+09          5.0 2015-01-01     10000.0
# 2       FortuneJack.com  1.201470e+08         29.0 2015-01-01     83000.0
# 3                   396  1.906135e+10         70.0 2015-01-01    540000.0
# 4      SatoshiMines.com  7.401319e+08        193.0 2015-01-01    740000.0
# ...                 ...           ...          ...        ...         ...
# 90339          BTCC.com  3.785757e+08         54.0 2017-06-30         0.0
# 90340         BTC-e.com  3.369045e+11       4265.0 2017-06-30  85002381.0
# 90341                35  2.808881e+10       1024.0 2017-06-30  65380833.0
# 90342       999Dice.com  8.133324e+08        422.0 2017-06-30   3005761.0
# 90343        HaoBTC.com  1.814966e+11       2016.0 2017-06-30  62579100.0
#
#        mean_fee_for100  nb_transactions          sent    self_spent  \
# 0             0.004957              4.0  1.277500e+09  0.000000e+00
# 1             0.000851              1.0  1.174552e+09  0.000000e+00
# 2             0.194670             11.0  1.541127e+08  1.415897e+07
# 3             0.023738             54.0  1.842989e+10  0.000000e+00
# 4             0.447934             45.0  1.813624e+09  3.504457e+07
# ...                ...              ...           ...           ...
# 90339         0.000000             12.0  3.785757e+08  0.000000e+00
# 90340         0.021072             74.0  5.887602e+11  0.000000e+00
# 90341         1.774006            402.0  2.851905e+10  0.000000e+00
# 90342         6.828742             59.0  2.058016e+08  1.704935e+07
# 90343         1.852587            287.0  2.409898e+11  5.517160e+10
#
#        self_spent_estimated  nb_spent         spent
# 0              0.000000e+00       8.0  1.277500e+09
# 1              0.000000e+00       2.0  1.174552e+09
# 2              1.415897e+07      22.0  1.399538e+08
# 3              0.000000e+00     108.0  1.842989e+10
# 4              3.504457e+07      84.0  1.778579e+09
# ...                     ...       ...           ...
# 90339          0.000000e+00      12.0  3.785757e+08
# 90340          5.733294e+11      74.0  1.543080e+10
# 90341          2.989980e+09     804.0  2.552907e+10
# 90342          1.704935e+07      91.0  1.887522e+08
# 90343          1.106820e+11     553.0  1.303077e+11
#
# [90344 rows x 12 columns]

# %%
# Change the nb_received and nb_transactions and nb_spent and sum_fee columns to integers
actor_blockchain = actor_blockchain.astype({'nb_received': 'int64', 'nb_transactions': 'int64', 'nb_spent': 'int64', 'sum_fee': 'int64'})
actor_blockchain
# Out:
#                identity      received  nb_received       date   sum_fee  \
# 0        HappyCoins.com  1.377590e+09            4 2015-01-01     49596
# 1                   821  2.476057e+09            5 2015-01-01     10000
# 2       FortuneJack.com  1.201470e+08           29 2015-01-01     83000
# 3                   396  1.906135e+10           70 2015-01-01    540000
# 4      SatoshiMines.com  7.401319e+08          193 2015-01-01    740000
# ...                 ...           ...          ...        ...       ...
# 90339          BTCC.com  3.785757e+08           54 2017-06-30         0
# 90340         BTC-e.com  3.369045e+11         4265 2017-06-30  85002381
# 90341                35  2.808881e+10         1024 2017-06-30  65380833
# 90342       999Dice.com  8.133324e+08          422 2017-06-30   3005761
# 90343        HaoBTC.com  1.814966e+11         2016 2017-06-30  62579100
#
#        mean_fee_for100  nb_transactions          sent    self_spent  \
# 0             0.004957                4  1.277500e+09  0.000000e+00
# 1             0.000851                1  1.174552e+09  0.000000e+00
# 2             0.194670               11  1.541127e+08  1.415897e+07
# 3             0.023738               54  1.842989e+10  0.000000e+00
# 4             0.447934               45  1.813624e+09  3.504457e+07
# ...                ...              ...           ...           ...
# 90339         0.000000               12  3.785757e+08  0.000000e+00
# 90340         0.021072               74  5.887602e+11  0.000000e+00
# 90341         1.774006              402  2.851905e+10  0.000000e+00
# 90342         6.828742               59  2.058016e+08  1.704935e+07
# 90343         1.852587              287  2.409898e+11  5.517160e+10
#
#        self_spent_estimated  nb_spent         spent
# 0              0.000000e+00         8  1.277500e+09
# 1              0.000000e+00         2  1.174552e+09
# 2              1.415897e+07        22  1.399538e+08
# 3              0.000000e+00       108  1.842989e+10
# 4              3.504457e+07        84  1.778579e+09
# ...                     ...       ...           ...
# 90339          0.000000e+00        12  3.785757e+08
# 90340          5.733294e+11        74  1.543080e+10
# 90341          2.989980e+09       804  2.552907e+10
# 90342          1.704935e+07        91  1.887522e+08
# 90343          1.106820e+11       553  1.303077e+11
#
# [90344 rows x 12 columns]

# %%
actor_blockchain.set_index('identity', inplace=True)
actor_blockchain = actor_blockchain.groupby([df.index, 'date']).sum()
actor_blockchain
# Out:
#                                        received  nb_received   sum_fee  \
# identity               date
# 0                      2015-01-01  3.021860e+10         4265  12350755
#                        2015-01-02  3.401216e+10         8395  15588104
#                        2015-01-03  2.546280e+11        10004  14742886
#                        2015-01-04  2.431648e+11         9007  18683447
#                        2015-01-05  4.882942e+10         6553  15866463
# ...                                         ...          ...       ...
# ePay.info_CoinJoinMess 2017-06-26  4.145836e+10         2207  16886012
#                        2017-06-27  7.856613e+10         2257  14640480
#                        2017-06-28  3.458316e+10         2122  13552028
#                        2017-06-29  3.611569e+10         1987  16592680
#                        2017-06-30  4.317324e+10         2438  18664735
#
#                                    mean_fee_for100  nb_transactions  \
# identity               date
# 0                      2015-01-01         1.926137              783
#                        2015-01-02         1.882565              962
#                        2015-01-03         1.984796              943
#                        2015-01-04         2.075441             1059
#                        2015-01-05         1.883876              995
# ...                                            ...              ...
# ePay.info_CoinJoinMess 2017-06-26         2.167302              257
#                        2017-06-27         1.677769              210
#                        2017-06-28         2.207943              209
#                        2017-06-29         2.638925              231
#                        2017-06-30         2.327340              277
#
#                                            sent    self_spent  \
# identity               date
# 0                      2015-01-01  3.001272e+10  0.000000e+00
#                        2015-01-02  3.400937e+10  0.000000e+00
#                        2015-01-03  2.517348e+11  0.000000e+00
#                        2015-01-04  2.429788e+11  0.000000e+00
#                        2015-01-05  4.926332e+10  0.000000e+00
# ...                                         ...           ...
# ePay.info_CoinJoinMess 2017-06-26  1.349778e+11  1.106631e+11
#                        2017-06-27  1.400648e+12  1.352502e+12
#                        2017-06-28  1.878307e+11  1.514641e+11
#                        2017-06-29  1.439742e+11  1.202103e+11
#                        2017-06-30  1.449515e+11  1.205214e+11
#
#                                    self_spent_estimated  nb_spent  \
# identity               date
# 0                      2015-01-01          0.000000e+00      1696
#                        2015-01-02          0.000000e+00      2068
#                        2015-01-03          2.011365e+11      2039
#                        2015-01-04          2.004149e+11      2293
#                        2015-01-05          0.000000e+00      2098
# ...                                                 ...       ...
# ePay.info_CoinJoinMess 2017-06-26          1.106631e+11      4849
#                        2017-06-27          1.352502e+12      4795
#                        2017-06-28          1.538256e+11      4742
#                        2017-06-29          1.202103e+11      4841
#                        2017-06-30          1.205214e+11      4930
#
#                                           spent
# identity               date
# 0                      2015-01-01  3.001272e+10
#                        2015-01-02  3.400937e+10
#                        2015-01-03  5.059830e+10
#                        2015-01-04  4.256388e+10
#                        2015-01-05  4.926332e+10
# ...                                         ...
# ePay.info_CoinJoinMess 2017-06-26  2.431475e+10
#                        2017-06-27  4.814597e+10
#                        2017-06-28  3.400519e+10
#                        2017-06-29  2.376388e+10
#                        2017-06-30  2.443010e+10
#
# [90344 rows x 10 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.plot(actor_blockchain.loc['Paymium.com'].index, actor_blockchain.loc['Paymium.com']['spent'], label='Paymium.com')
plt.plot(actor_blockchain.loc['HaoBTC.com'].index, actor_blockchain.loc['HaoBTC.com']['spent'], label='HaoBTC.com')
plt.plot(actor_blockchain.loc['OKCoin.com'].index, actor_blockchain.loc['OKCoin.com']['spent'], label='OKCoin.com')
plt.plot(actor_blockchain.loc['BTCC.com'].index, actor_blockchain.loc['BTCC.com']['spent'], label='BTCC.com')
plt.plot(actor_blockchain.loc['Poloniex.com'].index, actor_blockchain.loc['Poloniex.com']['spent'], label='Poloniex.com')
plt.legend()
plt.show()
