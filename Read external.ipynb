# %%
import pandas as pd
import os
import datetime
import matplotlib.pyplot as plt

path = './timeseries/external.csv'
df = pd.read_csv(path, sep=',', header=0, index_col=1, parse_dates=True)
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df.head()
# Out:
#               PriceUSD       HashRate
# date
# 2015-01-02  315.942732  333345.017260
# 2015-01-03  285.647310  327284.198765
# 2015-01-04  263.334575  347486.927083
# 2015-01-05  275.003852  315162.561773
# 2015-01-06  287.549521  319203.107437

# %%
df.dtypes
# Out:
# PriceUSD    float64
# HashRate    float64
# dtype: object

# %%
# log scale, dates between july 2015 and 2016
df['PriceUSD'].plot(figsize=(15, 5), logy=True)

plt.show()

# %%
# log scale, dates between july 2015 and 2016
df['PriceUSD'].plot(figsize=(15, 5), logy=True)
plt.xlim(datetime.date(2015, 7, 1), datetime.date(2016, 7, 1))
plt.show()
